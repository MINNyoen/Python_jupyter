# %% [markdown]
# # 주택월세종합지수

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
MR = pd.read_csv("../../Documents/Data/Project/유형별_주택월세통합가격지수.csv", encoding="utf-8", engine="python", index_col=0)
MR
# Out:
#             종합-전국[2017.11=100]  종합-수도권[2017.11=100]  종합-지방[2017.11=100]  \
# 2015-06-01               100.2                 99.6               100.8
# 2015-07-01               100.2                 99.6               100.8
# 2015-08-01               100.3                 99.6               100.9
# 2015-09-01               100.3                 99.7               100.9
# 2015-10-01               100.4                 99.8               101.0
# 2015-11-01               100.5                 99.8               101.0
# 2015-12-01               100.5                 99.8               101.0
# 2016-01-01               100.5                 99.8               101.0
# 2016-02-01               100.5                 99.8               101.0
# 2016-03-01               100.4                 99.8               101.0
# 2016-04-01               100.4                 99.8               101.0
# 2016-05-01               100.4                 99.8               101.0
# ...

# %%
MR.columns
# Out:
# Index(['종합-전국[2017.11=100]', '종합-수도권[2017.11=100]', '종합-지방[2017.11=100]',
#        '종합-5대광역시[2017.11=100]', '종합-8개도[2017.11=100]', '종합-서울[2017.11=100]',
#        '종합-경기[2017.11=100]', '종합-인천[2017.11=100]', '종합-부산[2017.11=100]',
#        '종합-대구[2017.11=100]', '종합-광주[2017.11=100]', '종합-대전[2017.11=100]',
#        '종합-울산[2017.11=100]', '종합-세종[2017.11=100]', '종합-강원[2017.11=100]',
#        '종합-충북[2017.11=100]', '종합-충남[2017.11=100]', '종합-전북[2017.11=100]',
#        '종합-전남[2017.11=100]', '종합-경북[2017.11=100]', '종합-경남[2017.11=100]',
#        '종합-제주[2017.11=100]', '종합-6대광역시[2017.11=100]', '종합-9개도[2017.11=100]',
#        '아파트-전국[2017.11=100]', '아파트-수도권[2017.11=100]', '아파트-지방[2017.11=100]',
#        '아파트-5대광역시[2017.11=100]', '아파트-8개도[2017.11=100]', '아파트-서울[2017.11=100]',
#        '아파트-경기[2017.11=100]', '아파트-인천[2017.11=100]', '아파트-부산[2017.11=100]',
#        '아파트-대구[2017.11=100]', '아파트-광주[2017.11=100]', '아파트-대전[2017.11=100]',
# ...

# %%
len(MR.columns)
MR
# Out:
#             종합-전국[2017.11=100]  종합-수도권[2017.11=100]  종합-지방[2017.11=100]  \
# 2015-06-01               100.2                 99.6               100.8
# 2015-07-01               100.2                 99.6               100.8
# 2015-08-01               100.3                 99.6               100.9
# 2015-09-01               100.3                 99.7               100.9
# 2015-10-01               100.4                 99.8               101.0
# 2015-11-01               100.5                 99.8               101.0
# 2015-12-01               100.5                 99.8               101.0
# 2016-01-01               100.5                 99.8               101.0
# 2016-02-01               100.5                 99.8               101.0
# 2016-03-01               100.4                 99.8               101.0
# 2016-04-01               100.4                 99.8               101.0
# 2016-05-01               100.4                 99.8               101.0
# ...

# %% [markdown]
# # 1. 종합 - 지역별(전국-수도권-지방)

# %%
MR
con = lambda x : x.split('-')[0].strip()
MR.index = MR.index.map(con)

# %%
MR_m = MR.groupby(MR.index).mean().filter(regex='^종합', axis=1)
MR_m
# Out:
#       종합-전국[2017.11=100]  종합-수도권[2017.11=100]  종합-지방[2017.11=100]  \
# 2015          100.342857            99.700000          100.914286
# 2016          100.375000            99.850000          100.866667
# 2017          100.133333            99.941667          100.316667
# 2018           99.425000            99.700000           99.158333
# 2019           98.283333            98.983333           97.650000
# 2020           98.375000            99.383333           97.458333
# 2021           99.533333           100.600000           98.566667
#
#       종합-5대광역시[2017.11=100]  종합-8개도[2017.11=100]  종합-서울[2017.11=100]  \
# 2015             100.457143           101.114286          100.000000
# 2016             100.358333           101.091667          100.058333
# 2017             100.083333           100.408333          100.000000
# 2018              99.425000            99.000000           99.858333
# 2019              98.233333            97.225000           99.416667
# ...

# %%
MR_m.iloc[0:,0:1].values
# Out:
# array([[100.34285714],
#        [100.375     ],
#        [100.13333333],
#        [ 99.425     ],
#        [ 98.28333333],
#        [ 98.375     ],
#        [ 99.53333333]])

# %%
MR_m.columns[0:3][0:3]
# Out:
# Index(['종합-전국[2017.11=100]', '종합-수도권[2017.11=100]', '종합-지방[2017.11=100]'], dtype='object')

# %%
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

f_path = "C:/Windows/Fonts/Hancom Gothic Regular.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
plt.plot(figsize=(30,10))
plt.plot(MR_m.index, MR_m.iloc[0:,0:1].values, label = "전국")
plt.plot(MR_m.index, MR_m.iloc[0:,1:2].values, label = "수도권")
plt.plot(MR_m.index, MR_m.iloc[0:,2:3].values, label = "지방")
plt.xlabel("연도")
plt.ylabel("주택가격지수\n(2017.11기준 = 100)")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
