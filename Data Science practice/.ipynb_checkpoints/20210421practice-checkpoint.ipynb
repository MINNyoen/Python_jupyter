# %%
import numpy as np
import pandas as pd

# %%
practice = pd.DataFrame({"이름": ["홍길동", "김길동"], "나이" : [100, 200]})
practice
# Out:
#     이름   나이
# 0  홍길동  100
# 1  김길동  200

# %%
practice1 = pd.DataFrame({"날짜":[],"운동":[], "양":[]})
practice1
# Out:
# Empty DataFrame
# Columns: [날짜, 운동, 양]
# Index: []

# %% [markdown]
# ## loc - 행인덱스 -> 행 추가 하기

# %%
practice1.loc[0]=['19-3-1', '달리기', 1]
practice1
# Out:
#        날짜   운동    양
# 0  19-3-1  달리기  1.0

# %%
practice1.loc[1]=['19-3-2', '수영', 1]
practice1.loc[2]=['19-3-3', '달리기', 2]
practice1.loc[3]=['19-3-4', '자전거', 1]
practice1.loc[4]=['19-3-5', '숨쉬기', 1]
practice1.loc[5]=['19-3-8', '걷기', 1.5]
practice1
# Out:
#        날짜   운동    양
# 0  19-3-1  달리기  1.0
# 1  19-3-2   수영  1.0
# 2  19-3-3  달리기  2.0
# 3  19-3-4  자전거  1.0
# 4  19-3-5  숨쉬기  1.0
# 5  19-3-8   걷기  1.5

# %%
practice.to_csv('practice1.csv', encoding='utf-8')

# %%
practice2=pd.read_csv('practice.csv', index_col=[0], encoding='utf-8')
practice2
# Out:
#        날짜     운동    양
# 0  19-3-1    달리기  1.0
# 1  19-3-2     걷기  1.0
# 2  19-3-2    달리기  1.0
# 3  19-3-2  계단오르기  1.0
# 4  19-3-3     걷기  1.5
# 5  19-3-3    달리기  1.0

# %% [markdown]
# ## AVG 기준

# %%
practice2.pivot_table(index='운동')
# Out:
#           양
# 운동
# 걷기     1.25
# 계단오르기  1.00
# 달리기    1.00

# %%
practice2.pivot_table(index='운동', aggfunc=np.sum)
# Out:
#          양
# 운동
# 걷기     2.5
# 계단오르기  1.0
# 달리기    3.0

# %%
practice2.pivot_table(index='운동', aggfunc=[np.sum, np.average, len])
# Out:
#        sum average len
#          양       양  날짜    양
# 운동
# 걷기     2.5    1.25   2  2.0
# 계단오르기  1.0    1.00   1  1.0
# 달리기    3.0    1.00   3  3.0

# %%
type(practice2)
# Out:
# pandas.core.frame.DataFrame

# %%
ne = pd.read_excel('reason_not_exercise.xls', index_col=[0], encoding='utf-8')
ne
# Out:
#         대분류            분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  \
# 기간
# 2017    서울시           서울시               49.7              8.1
# 2017     성별            남자               55.2              7.9
# 2017     성별            여자               45.0              8.3
# 2017    연령별           10대               55.7              6.1
# 2017    연령별           20대               54.8              6.9
# 2017    연령별           30대               58.1              5.5
# 2017    연령별           40대               57.7              6.8
# 2017    연령별           50대               50.1              9.2
# 2017    연령별        60대 이상               27.5             12.8
# 2017    학력별         중졸 이하               26.1             13.7
# 2017    학력별         고졸 이하               46.3              8.5
# 2017    학력별         대졸 이하               57.4              6.6
# 2017    학력별        대학원 이상               65.3              3.8
# 2017    소득별      100만원 미만               22.7             10.3
# ...
